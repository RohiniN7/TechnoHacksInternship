# %% [markdown]
# # TechnoHacks Internship

# %% [markdown]
# # Task 1 : Visualization using Histogram

# %% [markdown]
# # Dependencies

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading Dataset

# %%
iris=pd.read_csv('Iris.csv')

# %% [markdown]
# # Data Summary

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris.shape
# Out:
# (150, 6)

# %% [markdown]
# # Data Visualization using Scatter Plot

# %% [markdown]
# ## Basic Scatter Plot

# %%
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', data=iris)
plt.title('Sepal Length vs. Sepal Width')
# Out:
# Text(0.5, 1.0, 'Sepal Length vs. Sepal Width')

# %% [markdown]
# ## Scatter Plot - Category

# %%
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', hue='Species', data=iris)
plt.title('Sepal Length vs. Sepal Width')
# Out:
# Text(0.5, 1.0, 'Sepal Length vs. Sepal Width')

# %% [markdown]
# ## Scatter Plot with Regression Fit

# %%
sns.regplot(x='SepalLengthCm', y='SepalWidthCm', data=iris)
plt.title('Sepal Length vs. Sepal Width with Regression Fit')
# Out:
# Text(0.5, 1.0, 'Sepal Length vs. Sepal Width with Regression Fit')

# %% [markdown]
# # Line Plot

# %% [markdown]
# ## 1. SepalLengthCm vs SepalWidthCm

# %%
sns.lineplot(x='SepalLengthCm', y='SepalWidthCm', data=iris)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %% [markdown]
# ## 2. PetalLengthCm vs PetalWidthCm

# %%
sns.lineplot(x='PetalLengthCm', y='PetalWidthCm', data=iris)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %% [markdown]
# # Basic Histogram Plot

# %%
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.histplot(iris['SepalLengthCm'])
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.histplot(iris['SepalWidthCm'])
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Count'>

# %%
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.histplot(iris['PetalLengthCm'])
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Count'>

# %%
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)
sns.histplot(iris['PetalWidthCm'])
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Count'>

# %% [markdown]
# ### In conclusion, the task's culmination involved the visualization of diverse plots, including scatter plots, line plots, and histograms, based on the iris dataset.
# ### Through this visual exploration, we gained valuable insights into differentiating features such as Sepal Length, Sepal Width, Petal Length, and Petal Width.
# ### This analytical approach not only facilitated a comprehensive understanding of various Iris parameters but also contributed significantly to our deep learning and knowledge enhancement.
